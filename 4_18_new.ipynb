# %% [markdown]
# <a href="https://colab.research.google.com/github/optailor/4.18_new/blob/main/4_18_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(256):
  print(i, hex(i), bin(i))
# Out:
# 0 0x0 0b0
# 1 0x1 0b1
# 2 0x2 0b10
# 3 0x3 0b11
# 4 0x4 0b100
# 5 0x5 0b101
# 6 0x6 0b110
# 7 0x7 0b111
# 8 0x8 0b1000
# 9 0x9 0b1001
# 10 0xa 0b1010
# 11 0xb 0b1011
# 12 0xc 0b1100
# 13 0xd 0b1101
# 14 0xe 0b1110
# 15 0xf 0b1111
# 16 0x10 0b10000
# 17 0x11 0b10001
# 18 0x12 0b10010
# 19 0x13 0b10011
# 20 0x14 0b10100
# 21 0x15 0b10101
# 22 0x16 0b10110
# 23 0x17 0b10111
# 24 0x18 0b11000
# 25 0x19 0b11001
# 26 0x1a 0b11010
# 27 0x1b 0b11011
# 28 0x1c 0b11100
# 29 0x1d 0b11101
# 30 0x1e 0b11110
# 31 0x1f 0b11111
# 32 0x20 0b100000
# 33 0x21 0b100001
# 34 0x22 0b100010
# 35 0x23 0b100011
# 36 0x24 0b100100
# 37 0x25 0b100101
# 38 0x26 0b100110
# 39 0x27 0b100111
# 40 0x28 0b101000
# 41 0x29 0b101001
# 42 0x2a 0b101010
# 43 0x2b 0b101011
# 44 0x2c 0b101100
# 45 0x2d 0b101101
# 46 0x2e 0b101110
# 47 0x2f 0b101111
# 48 0x30 0b110000
# 49 0x31 0b110001
# 50 0x32 0b110010
# 51 0x33 0b110011
# 52 0x34 0b110100
# 53 0x35 0b110101
# 54 0x36 0b110110
# 55 0x37 0b110111
# 56 0x38 0b111000
# ...
